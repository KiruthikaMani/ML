# %%
import pickle #Pickle is a module or library and the dump/load inside it are called functions

# %%
loaded_model=pickle.load(open("finalized_model_RandomForestRegression.sav",'rb')) # load means loaded the trained model file with read binary mode
result=loaded_model.predict([[1234,345,4565,True,False]]) 

'''this is final step which means we can see the multiple linear regression 
output using by predict function'''
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 'this is final step which means we can see the multiple linear regression \noutput using by predict function'

# %%
result #output check ,profit for given input
# Out:
# array([47938.381])
